# %%
import pandas as pd
from sqlalchemy import create_engine
import datetime

# %%
# DATASOURCE 1: Extract all records from fundamentals.csv, prices.csv, securities.csv - source kaggle.com

fundamentals_csv = "csv_folder/fundamentals.csv"
prices_csv = "csv_folder/prices.csv"
securities_csv = "csv_folder/securities.csv"

fundamentals_df = pd.read_csv(fundamentals_csv)
prices_df = pd.read_csv(prices_csv)
securities_df = pd.read_csv(securities_csv)


fundamentals_df.head()
# Out:
#    Unnamed: 0 Ticker Symbol Period Ending  Accounts Payable  \
# 0           0           AAL    2012-12-31      3.068000e+09
# 1           1           AAL    2013-12-31      4.975000e+09
# 2           2           AAL    2014-12-31      4.668000e+09
# 3           3           AAL    2015-12-31      5.102000e+09
# 4           4           AAP    2012-12-29      2.409453e+09
#
#    Accounts Receivable  Add'l income/expense items  After Tax ROE  \
# 0         -222000000.0               -1.961000e+09           23.0
# 1          -93000000.0               -2.723000e+09           67.0
# 2         -160000000.0               -1.500000e+08          143.0
# 3          352000000.0               -7.080000e+08          135.0
# 4          -89482000.0                6.000000e+05           32.0
#
#    Capital Expenditures  Capital Surplus  Cash Ratio  ...  \
# 0         -1.888000e+09     4.695000e+09        53.0  ...
# 1         -3.114000e+09     1.059200e+10        75.0  ...
# ...

# %%
 
# iterating the columns 
for col in fundamentals_df.columns: 
    print(col)

#fundamentals_df = fundamentals_df['Accounts Receivable'].drop()
#fundamentals_df.head()
# Out:
# Unnamed: 0
# Ticker Symbol
# Period Ending
# Accounts Payable
# Accounts Receivable
# Add'l income/expense items
# After Tax ROE
# Capital Expenditures
# Capital Surplus
# Cash Ratio
# Cash and Cash Equivalents
# Changes in Inventories
# Common Stocks
# Cost of Revenue
# Current Ratio
# Deferred Asset Charges
# Deferred Liability Charges
# Depreciation
# Earnings Before Interest and Tax
# Earnings Before Tax
# Effect of Exchange Rate
# Equity Earnings/Loss Unconsolidated Subsidiary
# Fixed Assets
# Goodwill
# Gross Margin
# Gross Profit
# Income Tax
# Intangible Assets
# Interest Expense
# Inventory
# Investments
# Liabilities
# Long-Term Debt
# Long-Term Investments
# Minority Interest
# Misc. Stocks
# Net Borrowings
# Net Cash Flow
# Net Cash Flow-Operating
# Net Cash Flows-Financing
# Net Cash Flows-Investing
# Net Income
# Net Income Adjustments
# Net Income Applicable to Common Shareholders
# Net Income-Cont. Operations
# Net Receivables
# Non-Recurring Items
# Operating Income
# ...

# %%
x = ['Ticker Symbol','Period Ending','Net Borrowings','Net Income','Total Revenue','Long-Term Debt','Capital Expenditures']


fundamentals_df = fundamentals_df[x].copy()
fundamentals_df = fundamentals_df.rename(columns={
                                                  'Period Ending':'date'
                                            
                                           
})
fundamentals_df.head()
# Out:
#   Ticker Symbol        date  Net Borrowings    Net Income  Total Revenue  \
# 0           AAL  2012-12-31   -1.020000e+09 -1.876000e+09   2.485500e+10
# 1           AAL  2013-12-31    2.208000e+09 -1.834000e+09   2.674300e+10
# 2           AAL  2014-12-31    1.700000e+08  2.882000e+09   4.265000e+10
# 3           AAL  2015-12-31    2.856000e+09  7.610000e+09   4.099000e+10
# 4           AAP  2012-12-29    1.774450e+08  3.876700e+08   6.205003e+09
#
#    Long-Term Debt  Capital Expenditures
# 0    7.116000e+09         -1.888000e+09
# 1    1.535300e+10         -3.114000e+09
# 2    1.604300e+10         -5.311000e+09
# 3    1.833000e+10         -6.151000e+09
# 4    6.044610e+08         -2.711820e+08

# %%
fundamentals_df.count()
# Out:
# Ticker Symbol           1781
# date                    1781
# Net Borrowings          1781
# Net Income              1781
# Total Revenue           1781
# Long-Term Debt          1781
# Capital Expenditures    1781
# dtype: int64

# %%
prices_df.head()
# Out:
#          date symbol        open       close         low        high  \
# 0  2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000
# 1  2016-01-06   WLTW  125.239998  119.980003  119.940002  125.540001
# 2  2016-01-07   WLTW  116.379997  114.949997  114.930000  119.739998
# 3  2016-01-08   WLTW  115.480003  116.620003  113.500000  117.440002
# 4  2016-01-11   WLTW  117.010002  114.970001  114.089996  117.330002
#
#       volume
# 0  2163600.0
# 1  2386400.0
# 2  2489500.0
# 3  2006300.0
# 4  1408600.0

# %%
prices_df.count()
# Out:
# date      851264
# symbol    851264
# open      851264
# close     851264
# low       851264
# high      851264
# volume    851264
# dtype: int64

# %%
q = ['date','symbol','close','volume']


prices_df = prices_df[q].copy()

prices_df = prices_df.rename(columns={
                                                  'symbol':'Ticker symbol'                                   
})
prices_df.head()
# Out:
#          date Ticker symbol       close     volume
# 0  2016-01-05          WLTW  125.839996  2163600.0
# 1  2016-01-06          WLTW  119.980003  2386400.0
# 2  2016-01-07          WLTW  114.949997  2489500.0
# 3  2016-01-08          WLTW  116.620003  2006300.0
# 4  2016-01-11          WLTW  114.970001  1408600.0

# %%
securities_df.head()
# Out:
#   Ticker symbol             Security SEC filings             GICS Sector  \
# 0           MMM           3M Company     reports             Industrials
# 1           ABT  Abbott Laboratories     reports             Health Care
# 2          ABBV               AbbVie     reports             Health Care
# 3           ACN        Accenture plc     reports  Information Technology
# 4          ATVI  Activision Blizzard     reports  Information Technology
#
#                 GICS Sub Industry   Address of Headquarters Date first added  \
# 0        Industrial Conglomerates       St. Paul, Minnesota              NaN
# 1           Health Care Equipment   North Chicago, Illinois       1964-03-31
# 2                 Pharmaceuticals   North Chicago, Illinois       2012-12-31
# 3  IT Consulting & Other Services           Dublin, Ireland       2011-07-06
# 4     Home Entertainment Software  Santa Monica, California       2015-08-31
#
#        CIK
# 0    66740
# 1     1800
# 2  1551152
# 3  1467373
# ...

# %%
yo = ['Ticker symbol','Security','GICS Sector','GICS Sub Industry', 'Date first added']


securities_df = securities_df[yo].copy()
# securities_df = securities_df.rename(columns={'Ticker Symbol':'symbol',
#                                               'Security':'symbol'
# })
securities_df.head()
# Out:
#   Ticker symbol             Security             GICS Sector  \
# 0           MMM           3M Company             Industrials
# 1           ABT  Abbott Laboratories             Health Care
# 2          ABBV               AbbVie             Health Care
# 3           ACN        Accenture plc  Information Technology
# 4          ATVI  Activision Blizzard  Information Technology
#
#                 GICS Sub Industry Date first added
# 0        Industrial Conglomerates              NaN
# 1           Health Care Equipment       1964-03-31
# 2                 Pharmaceuticals       2012-12-31
# 3  IT Consulting & Other Services       2011-07-06
# 4     Home Entertainment Software       2015-08-31

# %%
#merged_fundamentals_price = fundamentals_df.merge(prices_df, on='symbol', how='left')
merged_fundamentals_price_securities = merged_fundamentals_price.merge(securities_df, on=['Ticker symbol'],how='left')
merged_fundamentals_price = fundamentals_df.merge(prices_df, on=['date','Ticker symbol'],how='left')

#merged_fundamentals_price = fundamentals_df.merge(prices_df, on='date', how='left')
#df_wine_data = df_wine_data.merge(df_provinces, on='province_name', how='inner')
merged_fundamentals_price_securities.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-132e24374590> in <module>
#       1 #merged_fundamentals_price = fundamentals_df.merge(prices_df, on='symbol', how='left')
# ----> 2 a = fundamentals_df.merge(securities_df, on=['Ticker symbol'],how='left')
#       3 b = a.merge(prices_df, on=['date','Ticker symbol'],how='left')
#       4
#       5 #merged_fundamentals_price = fundamentals_df.merge(prices_df, on='date', how='left')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7332             copy=copy,
#    7333             indicator=indicator,
# -> 7334             validate=validate,
#    7335         )
#    7336
#
# ...

# %%
merged_fundamentals_price.count()
